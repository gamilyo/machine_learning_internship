# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0-beta1

# %%
features = pd.read_excel('feature.xlsx',header=1)
train = pd.read_csv('train_label.csv')

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 983 entries, 0 to 982
# Columns: 132 entries, Unnamed: 0 to 136676754.4
# dtypes: datetime64[ns](1), float64(103), int64(27), object(1)
# memory usage: 1013.8+ KB

# %%
train.date.dtype,features.date.dtype
# Out:
# (dtype('O'), dtype('<M8[ns]'))

# %%
train.date = pd.to_datetime(train.date)

# %%
features.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
train.dropna(inplace=True)

# %%
features = features.loc[features['date'].isin(train.date)]

# %%
len(train) - len(features)
# Out:
# 28

# %%
thresh = len(features) * .5
features.dropna(thresh = thresh, axis = 1, inplace = True)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485 entries, 2 to 578
# Data columns (total 35 columns):
# date           485 non-null datetime64[ns]
# 136088194      485 non-null int64
# 136088202      485 non-null int64
# 136088394      485 non-null int64
# 136088802      485 non-null int64
# 136089546      485 non-null int64
# 136110468      485 non-null int64
# 136216674      485 non-null int64
# 136222202      485 non-null int64
# 136222210      485 non-null int64
# 136222234      485 non-null int64
# 136222250      485 non-null int64
# 136222882      485 non-null int64
# 136223186      485 non-null int64
# 136224578      485 non-null int64
# 136224586      485 non-null int64
# 136224978      485 non-null int64
# 136225010      485 non-null int64
# 136675426      485 non-null int64
# 136675626      485 non-null int64
# 136676578      485 non-null int64
# 136676650      485 non-null int64
# 136676666      485 non-null int64
# 136676682      485 non-null int64
# 136676698      485 non-null int64
# 136676714      485 non-null int64
# 136676754      485 non-null int64
# 136110468.1    435 non-null float64
# 136225010.1    251 non-null float64
# 136110468.2    435 non-null float64
# 136225010.2    251 non-null float64
# 136110468.3    435 non-null float64
# 136225010.3    251 non-null float64
# 136110468.4    435 non-null float64
# 136225010.4    251 non-null float64
# dtypes: datetime64[ns](1), float64(8), int64(26)
# memory usage: 136.4 KB

# %%
features.fillna(features.mean(),inplace=True)

# %%
features['label'] = train.label[train['date'].isin(features.date)]

# %%
features.dropna(inplace=True)

# %%
features.isna().sum().any()
# Out:
# False

# %%
def plot_series(time, series, start=0, end=None):
    plt.scatter(time[start:end], series[start:end])
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
date = features.date

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
data = features.drop(['date','label'],axis=1)

# %%
data.shape
# Out:
# (463, 34)

# %%
data = pd.DataFrame(scaler.fit_transform(data))
# Out:
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
def supervise(data,target,window_size):
    dataset = []
    labels = []
    for i in range(window_size,(len(data))):
        dataset.append(data.loc[i-window_size:i-1].values)
        labels.append(target[i])
    return dataset,labels

# %%
data.index = [i for i in range(0,len(data))]

# %%
labels = features.label.to_list()

# %%
datset,target = supervise(data,labels,10)

# %%
len(datset),len(target)
# Out:
# (453, 453)

# %%
dataset  = np.concatenate(datset).reshape(453,10,34)

# %%
time = np.array([i for i in range(0,len(datset))])

# %%
plt.figure(figsize=(10, 6))
plot_series(time, target)

# %%
pd.Series(target).value_counts()
# Out:
# 0.0    429
# 1.0     24
# dtype: int64

# %%
values = features.drop(['date','label'],axis=1).values
# specify columns to plot
groups = [i for i in range(0,34)]
i = 1
# plot each column
plt.figure(figsize=(20,15))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(features.drop(['date','label'],axis=1).columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
split_time = 300
time_train = time[:split_time]
x_train = dataset[:split_time]
y_train = labels[:split_time]
time_valid = time[split_time:]
x_valid = dataset[split_time:]
y_valid = target[split_time:]

# %%
len(time),len(datset),len(target)
# Out:
# (453, 453, 453)

# %%
x_valid.shape
# Out:
# (153, 10, 34)

# %%
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
tf.keras.layers.Conv1D(filters=60, kernel_size=5,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=(10,34)),
tf.keras.layers.LSTM(256, return_sequences=True),
tf.keras.layers.LSTM(128, return_sequences=True),
tf.keras.layers.Flatten(),
tf.keras.layers.Dense(32, activation="relu"),
tf.keras.layers.Dense(1,activation='sigmoid')])

# %%
x_train = x_train.reshape((300,10,34))
x_valid = x_valid.reshape((153,10,34))

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.BinaryCrossentropy()
              , metrics=['accuracy'])

# %%
model.fit(x_train,np.array(y_train),batch_size=32,steps_per_epoch=np.ceil(x_train.shape[0] / 32),epochs=10,validation_data=(x_valid,np.array(y_valid)))
# Out:
# Train on 10.0 samples, validate on 153 samples
# Epoch 1/100
# 10/10 [==============================] - 8s 849ms/step - loss: 0.3599 - accuracy: 0.8907 - val_loss: 0.3681 - val_accuracy: 0.9281
# Epoch 2/100
# 10/10 [==============================] - 4s 404ms/step - loss: 0.1821 - accuracy: 0.9600 - val_loss: 0.2631 - val_accuracy: 0.9281
# Epoch 3/100
# 10/10 [==============================] - 4s 386ms/step - loss: 0.1599 - accuracy: 0.9600 - val_loss: 0.2782 - val_accuracy: 0.9281
# Epoch 4/100
# 10/10 [==============================] - 4s 390ms/step - loss: 0.1383 - accuracy: 0.9647 - val_loss: 0.3064 - val_accuracy: 0.9281
# Epoch 5/100
# 10/10 [==============================] - 4s 414ms/step - loss: 0.1092 - accuracy: 0.9713 - val_loss: 0.3360 - val_accuracy: 0.9216
# Epoch 6/100
# 10/10 [==============================] - 4s 379ms/step - loss: 0.0696 - accuracy: 0.9847 - val_loss: 0.3992 - val_accuracy: 0.9150
# Epoch 7/100
# 10/10 [==============================] - 4s 441ms/step - loss: 0.0466 - accuracy: 0.9897 - val_loss: 0.4631 - val_accuracy: 0.9085
# Epoch 8/100
# 10/10 [==============================] - 4s 400ms/step - loss: 0.0263 - accuracy: 0.9940 - val_loss: 0.7752 - val_accuracy: 0.8889
# Epoch 9/100
# 10/10 [==============================] - 4s 428ms/step - loss: 0.0081 - accuracy: 0.9983 - val_loss: 0.9259 - val_accuracy: 0.8889
# Epoch 10/100
# 10/10 [==============================] - 5s 466ms/step - loss: 2.5137e-04 - accuracy: 1.0000 - val_loss: 1.0785 - val_accuracy: 0.9020
# Epoch 11/100
# 10/10 [==============================] - 4s 389ms/step - loss: 7.2276e-05 - accuracy: 1.0000 - val_loss: 1.2484 - val_accuracy: 0.9020
# Epoch 12/100
# 10/10 [==============================] - 4s 406ms/step - loss: 6.3902e-06 - accuracy: 1.0000 - val_loss: 1.2985 - val_accuracy: 0.9085
# Epoch 13/100
# 10/10 [==============================] - 4s 395ms/step - loss: 2.2707e-06 - accuracy: 1.0000 - val_loss: 1.3171 - val_accuracy: 0.9085
# Epoch 14/100
# 10/10 [==============================] - 4s 400ms/step - loss: 1.2298e-06 - accuracy: 1.0000 - val_loss: 1.3237 - val_accuracy: 0.9085
# Epoch 15/100
# 10/10 [==============================] - 4s 380ms/step - loss: 9.2988e-07 - accuracy: 1.0000 - val_loss: 1.3345 - val_accuracy: 0.9085
# Epoch 16/100
# 10/10 [==============================] - 4s 381ms/step - loss: 8.1422e-07 - accuracy: 1.0000 - val_loss: 1.3301 - val_accuracy: 0.9085
# Epoch 17/100
# 10/10 [==============================] - 4s 384ms/step - loss: 7.5308e-07 - accuracy: 1.0000 - val_loss: 1.3380 - val_accuracy: 0.9085
# Epoch 18/100
# 10/10 [==============================] - 4s 440ms/step - loss: 7.1116e-07 - accuracy: 1.0000 - val_loss: 1.3386 - val_accuracy: 0.9085
# Epoch 19/100
# 10/10 [==============================] - 4s 442ms/step - loss: 6.7822e-07 - accuracy: 1.0000 - val_loss: 1.3344 - val_accuracy: 0.9085
# Epoch 20/100
# 10/10 [==============================] - 5s 476ms/step - loss: 6.5137e-07 - accuracy: 1.0000 - val_loss: 1.3409 - val_accuracy: 0.9085
# Epoch 21/100
# 10/10 [==============================] - 5s 511ms/step - loss: 6.2753e-07 - accuracy: 1.0000 - val_loss: 1.3413 - val_accuracy: 0.9085
# Epoch 22/100
# 10/10 [==============================] - 5s 467ms/step - loss: 6.0532e-07 - accuracy: 1.0000 - val_loss: 1.3396 - val_accuracy: 0.9020
# Epoch 23/100
# 10/10 [==============================] - 4s 396ms/step - loss: 5.8408e-07 - accuracy: 1.0000 - val_loss: 1.3429 - val_accuracy: 0.9020
# Epoch 24/100
# 10/10 [==============================] - 5s 485ms/step - loss: 5.6600e-07 - accuracy: 1.0000 - val_loss: 1.3444 - val_accuracy: 0.9020
# Epoch 25/100
# 10/10 [==============================] - 5s 549ms/step - loss: 5.4738e-07 - accuracy: 1.0000 - val_loss: 1.3419 - val_accuracy: 0.9020
# Epoch 26/100
# 10/10 [==============================] - 5s 483ms/step - loss: 5.2999e-07 - accuracy: 1.0000 - val_loss: 1.3438 - val_accuracy: 0.9020
# Epoch 27/100
# 10/10 [==============================] - 4s 399ms/step - loss: 5.1340e-07 - accuracy: 1.0000 - val_loss: 1.3458 - val_accuracy: 0.9020
# Epoch 28/100
# 10/10 [==============================] - 4s 376ms/step - loss: 4.9854e-07 - accuracy: 1.0000 - val_loss: 1.3447 - val_accuracy: 0.9020
# Epoch 29/100
# 10/10 [==============================] - 4s 368ms/step - loss: 4.8273e-07 - accuracy: 1.0000 - val_loss: 1.3486 - val_accuracy: 0.9020
# Epoch 30/100
# 10/10 [==============================] - 4s 431ms/step - loss: 4.6928e-07 - accuracy: 1.0000 - val_loss: 1.3491 - val_accuracy: 0.9020
# Epoch 31/100
# 10/10 [==============================] - 5s 505ms/step - loss: 4.5588e-07 - accuracy: 1.0000 - val_loss: 1.3497 - val_accuracy: 0.9020
# Epoch 32/100
# 10/10 [==============================] - 5s 519ms/step - loss: 4.4299e-07 - accuracy: 1.0000 - val_loss: 1.3491 - val_accuracy: 0.9020
# Epoch 33/100
# 10/10 [==============================] - 5s 545ms/step - loss: 4.3099e-07 - accuracy: 1.0000 - val_loss: 1.3490 - val_accuracy: 0.9020
# Epoch 34/100
# 10/10 [==============================] - 5s 478ms/step - loss: 4.1893e-07 - accuracy: 1.0000 - val_loss: 1.3476 - val_accuracy: 0.9020
# Epoch 35/100
# 10/10 [==============================] - 5s 479ms/step - loss: 4.0711e-07 - accuracy: 1.0000 - val_loss: 1.3491 - val_accuracy: 0.9020
# Epoch 36/100
#  7/10 [====================>.........] - ETA: 1s - loss: 3.9692e-07 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-3e07e1f678db> in <module>
# ----> 1 model.fit(x_train,np.array(y_train),batch_size=32,steps_per_epoch=np.ceil(x_train.shape[0] / 32),epochs=100,validation_data=(x_valid,np.array(y_valid)))
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     641         max_queue_size=max_queue_size,
#     642         workers=workers,
# --> 643         use_multiprocessing=use_multiprocessing)
#     644
#     645   def evaluate(self,
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     662         validation_steps=validation_steps,
#     663         validation_freq=validation_freq,
# --> 664         steps_name='steps_per_epoch')
#     665
#     666   def evaluate(self,
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     292           else:
#     293             actual_inputs = ins()
# --> 294           batch_outs = f(actual_inputs)
#     295         except errors.OutOfRangeError:
#     296           if is_dataset:
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3508         value = math_ops.cast(value, tensor.dtype)
#    3509       converted_inputs.append(value)
# -> 3510     outputs = self._graph_fn(*converted_inputs)
#    3511
#    3512     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#     570       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     571           list(kwargs.keys()), list(self._arg_keywords)))
# --> 572     return self._call_flat(args)
#     573
#     574   def _filtered_call(self, args, kwargs):
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args)
#     669     # Only need to override the gradient in graph mode and when we have outputs.
#     670     if context.executing_eagerly() or not self.outputs:
# --> 671       outputs = self._inference_function.call(ctx, args)
#     672     else:
#     673       self._register_gradient()
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args)
#     443             attrs=("executor_type", executor_type,
#     444                    "config_proto", config),
# --> 445             ctx=ctx)
#     446       # Replace empty list with None
#     447       outputs = outputs or None
#
# c:\users\lenovo_pc\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
np.array(y_train).shape

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 10, 60)            10260
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 10, 256)           324608
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 10, 128)           197120
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                40992
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 573,013
# Trainable params: 573,013
# Non-trainable params: 0
# _________________________________________________________________
